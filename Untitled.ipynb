# %%
import os
import random
#import tensorflow as tf
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()
import numpy as np
import gym
import imageio
from skimage.transform import resize
# Out:
# WARNING:tensorflow:From C:\Users\atanas.vasev\AppData\Local\anaconda3\envs\py36\lib\site-packages\tensorflow_core\python\compat\v2_compat.py:88: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
ENV_NAME = 'BreakoutDeterministic-v4'

# %%
import gym

# Create the Breakout environment
env = gym.make('BreakoutDeterministic-v4')  # You can also use 'BreakoutDeterministic-v3'

# Reset the environment
frame = env.reset()

# Loop for 1000 steps
for i in range(1000):
    # Take a random action (0 for simplicity)
    action = env.action_space.sample()
    
    # Perform the action and observe the new frame, reward, terminal, and info
    new_frame, reward, terminal, info = env.step(action)
    
    # Print the reward, terminal, and available keys in the info dictionary
    print("Step:", i, "Reward:", reward, "Terminal:", terminal, "Info Keys:", info.keys())
    
    # Break the loop if the episode is terminated
    if terminal:
        break
# Out:
# Step: 0 Reward: 0.0 Terminal: False Info Keys: dict_keys(['lives', 'episode_frame_number', 'frame_number'])
# Step: 1 Reward: 0.0 Terminal: False Info Keys: dict_keys(['lives', 'episode_frame_number', 'frame_number'])
# Step: 2 Reward: 0.0 Terminal: False Info Keys: dict_keys(['lives', 'episode_frame_number', 'frame_number'])
# Step: 3 Reward: 0.0 Terminal: False Info Keys: dict_keys(['lives', 'episode_frame_number', 'frame_number'])
# Step: 4 Reward: 0.0 Terminal: False Info Keys: dict_keys(['lives', 'episode_frame_number', 'frame_number'])
# Step: 5 Reward: 0.0 Terminal: False Info Keys: dict_keys(['lives', 'episode_frame_number', 'frame_number'])
# Step: 6 Reward: 0.0 Terminal: False Info Keys: dict_keys(['lives', 'episode_frame_number', 'frame_number'])
# Step: 7 Reward: 0.0 Terminal: False Info Keys: dict_keys(['lives', 'episode_frame_number', 'frame_number'])
# Step: 8 Reward: 0.0 Terminal: False Info Keys: dict_keys(['lives', 'episode_frame_number', 'frame_number'])
# ...

# %%
import gym

# Create the Breakout environment
env = gym.make('BreakoutDeterministic-v4')  # You can also use 'BreakoutDeterministic-v3'

# Reset the environment
frame = env.reset()

# Loop for 1000 steps
for i in range(1000):
    # Take a random action (0 for simplicity)
    action = env.action_space.sample()
    
    # Perform the action and observe the new frame, reward, terminal, and info
    new_frame, reward, terminal, info = env.step(action)
    
    # Print the reward, terminal, and number of lives
    print("Step:", i, "Reward:", reward, "Terminal:", terminal, "Lives:", info['lives'])
    
    # Break the loop if the episode is terminated
    if terminal:
        break
# Out:
# Step: 0 Reward: 0.0 Terminal: False Lives: 5
# Step: 1 Reward: 0.0 Terminal: False Lives: 5
# Step: 2 Reward: 0.0 Terminal: False Lives: 5
# Step: 3 Reward: 0.0 Terminal: False Lives: 5
# Step: 4 Reward: 0.0 Terminal: False Lives: 5
# Step: 5 Reward: 0.0 Terminal: False Lives: 5
# Step: 6 Reward: 0.0 Terminal: False Lives: 5
# Step: 7 Reward: 0.0 Terminal: False Lives: 5
# Step: 8 Reward: 0.0 Terminal: False Lives: 5
# Step: 9 Reward: 0.0 Terminal: False Lives: 5
# Step: 10 Reward: 0.0 Terminal: False Lives: 5
# Step: 11 Reward: 0.0 Terminal: False Lives: 5
# Step: 12 Reward: 0.0 Terminal: False Lives: 5
# Step: 13 Reward: 0.0 Terminal: False Lives: 5
# Step: 14 Reward: 0.0 Terminal: False Lives: 5
# Step: 15 Reward: 0.0 Terminal: False Lives: 5
# Step: 16 Reward: 0.0 Terminal: False Lives: 5
# Step: 17 Reward: 0.0 Terminal: False Lives: 5
# Step: 18 Reward: 0.0 Terminal: False Lives: 5
# Step: 19 Reward: 0.0 Terminal: False Lives: 5
# Step: 20 Reward: 0.0 Terminal: False Lives: 5
# ...
